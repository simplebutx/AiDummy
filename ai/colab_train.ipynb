# %% [markdown]
# # AI 분류 모델 학습용 Colab 노트북
#
# 이 노트북은 `ai/train_model.py`를 Colab에서 실행해서 모델 파일을 만드는 용도입니다.

# %% [markdown]
# ## 1. 프로젝트 업로드
#
# - `AiDummy/ai` 폴더를 zip으로 올리거나
# - Google Drive에 올려둔 뒤 마운트해서 사용하세요.

# %%
from google.colab import files
uploaded = files.upload()

# %%
# !unzip -o ai.zip -d /content

# %% [markdown]
# ## 2. 폴더 이동 및 패키지 설치

# %%
# %cd /content/ai
# !pip install -r requirements.txt

# %% [markdown]
# ## 3. 학습 실행

# %%
# !python train_model.py

# %% [markdown]
# ## 4. 생성된 모델 파일 확인

# %%
# !ls -R artifacts

# %% [markdown]
# ## 5. 결과 파일 다운로드
#
# 다운로드한 두 파일을 로컬 프로젝트의 `ai/artifacts` 폴더에 넣으면 됩니다.

# %%
from google.colab import files
files.download('artifacts/classification_pipeline.joblib')
files.download('artifacts/classification_metadata.json')
